# %% [markdown]
# # Assignment

# %%
# Strings
data = 'Hello World'
print (data[0])
print (len(data))
print (data)

# %%
# Numbers
value = 50.4
print (value)
value = 5.6
print (value)

# %%
# Boolean
p = True
q = False
print (p,q)

# %%
# Multiple Assignment
p,q,r = 5,6,7
print (p,q,r)

# %%
# No value
p = None
print (p)
