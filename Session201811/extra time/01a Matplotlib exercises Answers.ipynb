# %% [markdown]
# # Matplotlib exercise
#
# 1. Line Plot
# 1. Bar chart
# 1. Bar chart - multiple inputs
# 1. Bar chart - stacked
# 1. Scatter plot data

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
# Line Plot data
myArray = np.array([ 7,  8,  9, 10, 12, 13, 15, 16,
       17, 18, 20, 22, 23, 24, 25, 23, 22,  20, 19, 17, 16, 15, 13, 12, 11])

# %%
plt.plot(myArray)
plt.xlabel('Some x-axis label')
plt.ylabel('Some y-axis label')
plt.title('Line Plot')
plt.show()

# %%
# Bar chart plot data
important = (0,0,4,3,10,21)
data_range = np.arange(6)

# %%
plt.bar(important,data_range)
plt.show()

# %%
# Bar chart plot data - multiple inputs
important = (0,0,4,3,15,10)
current =(1,1,16,10,8,2)
N = 6

# %%
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, important, width, color='r')
p2 = plt.bar(ind + width, current, width, color='y')

plt.yticks(np.arange(0, 21, 5))
plt.ylabel('Scores')
plt.legend((p1[0], p2[0]), ('Important', 'Current'))

plt.show()

# %%
# Bar chart plot data stacked - multiple inputs
important = (3,0,4,7,16,8)
current =(0,4,16,11,5,2)
N = 6

# %%
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, important, width, color='r')
p2 = plt.bar(ind, current, width, color='y', bottom=important )

plt.yticks(np.arange(0, 31, 5))
plt.ylabel('Scores')
plt.legend((p1[0], p2[0]), ('Important', 'Current'))

plt.show()

# %%
# Scatter plot data
# Alligator data snout length and weight
alligatorLength = np.array([3.87, 3.61, 4.33, 3.43, 3.81, 3.83, 3.46, 3.76, 3.50, 3.58, 4.19, 3.78, 3.71, 3.73, 3.78])
alligatorWeight = np.array([4.87, 3.93, 6.46, 3.33, 4.38, 4.70, 3.50, 4.50, 3.58, 3.64, 5.90, 4.43, 4.38, 4.42, 4.25])

# %%
plt.scatter(alligatorLength, alligatorWeight, c='g') # c='g' for green
plt.xlabel('Alligator Snout Length')
plt.ylabel('Alligator Weight')
plt.title('Alligator')
plt.show()
